# %% [markdown]
# <a href="https://colab.research.google.com/github/BhanuPrakash-Guniganti/python-for-ml/blob/main/mov_rec_sys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
pd.read_csv('cleaned_movies.csv')
# Out:
#                                          title  \
# 0                                       Avatar
# 1     Pirates of the Caribbean: At World's End
# 2                                      Spectre
# 3                        The Dark Knight Rises
# 4                                  John Carter
# ...                                        ...
# 4770                                    Cavite
# 4771                               El Mariachi
# 4772                                 Newlyweds
# 4773                 Signed, Sealed, Delivered
# 4774                         My Date with Drew
#
#                                             genre  year
# 0     Action, Adventure, Fantasy, Science Fiction  2009
# 1                      Adventure, Fantasy, Action  2007
# 2                        Action, Adventure, Crime  2015
# 3                  Action, Crime, Drama, Thriller  2012
# 4              Action, Adventure, Science Fiction  2012
# ...                                           ...   ...
# ...

# %%
data['genres'] = data['genres'].str.lower()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_602/3971995804.py in <cell line: 0>()
# ----> 1 data['genres'] = data['genres'].str.lower()
#
# NameError: name 'data' is not defined
