# %% [markdown]
# <a href="https://colab.research.google.com/github/BhanuPrakash-Guniganti/python-for-ml/blob/main/mov_rec_sys.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('movies_cleaned.csv')

# %%
lower = data['genre'] = data['genre'].str.lower()
data['title'] = data['title'].str.title()

# %%
genre=input("enter genre(e.g.,action,comedy):").lower()
start_year=int(input("enter start year:"))
end_year=int(input("enter end year:"))
# Out:
# enter genre(e.g.,action,comedy):action
# enter start year:2000
# enter end year:2025

# %%
filtered = data[
    (data['genre'].str.contains(genre, na=True)) &
    (data['year'] >= start_year) &
     (data['year'] <= end_year)]

# %%
filtered=filtered.sort_values(by='year',ascending=True)

# %%
for year in sorted(filtered['year'].unique()):
  print(f"\nYear",{int(year)})
  movies = filtered[filtered['year'] == year]

  for title in movies['title'].head(5):
    print(f"{title}")
# Out:
# Year {2000}
# Manoharam
# Baachi
# Rayalaseema Ramanna Chowdary
# Vamsee
# Azaad
#
# Year {2001}
# Mrugaraaju
# Narasimha Naidu
# Adhipathi
# Student No. 1
# Aalavandhan
#
# Year {2002}
# Takkari Donga
# Chenna Kesava Reddy
# Jayam
# Idiot
# Sontham
#
# Year {2003}
# Veede
# Kadhal Sadugudu
# Aithe
# Palnati Brahmanayudu
# Nijam
#
# Year {2004}
# Yagnam
# Arya
# Vijayendra Varama
# Anji
# Samba
#
# Year {2005}
# Bhageeratha
# Andarivaadu
# Chatrapathi
# Athanokkade
# Andhrudu
#
# Year {2006}
# Stalin
# Pournami
# Annavaram
# Khatarnak
# Bangaram
#
# Year {2007}
# Lakshmi Kalyanam
# Desamuduru
# Athidhi
# Jagadam
# Yogi
#
# Year {2008}
# Sathyam
# Aatadista
# Baladoor
# Ontari
# Bujjigaadu: Made In Chennai
#
# Year {2009}
# Maska
# Arya 2
# Baanam
# Ek Niranjan
# Quick Gun Murugun: Misadventures Of An Indian Cowboy
#
# Year {2010}
# Gaayam 2
# Khaleja
# Vedam
# Kalyan Ram Kathi
# Police Police
#
# Year {2011}
# Veera
# Gaganam
# Ra.One
# Mirapakai
# 7 Aum Arivu
#
# Year {2012}
# ...
